# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os

#os.environ['CUDA_LAUNCH_BLOCKING'] = '1'


import torch, torchvision
from torch import nn
from pathlib import Path
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import RandomCrop, RandomHorizontalFlip, RandomRotation
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from timeit import default_timer as timer
from tqdm import tqdm
from typing import List, Tuple, Dict
from skimage import io, transform, color
from torchvision.transforms import functional as F

# !pip install elasticdeform
import elasticdeform

import random

import cv2

from PIL import Image

import numpy as np

import multiprocessing as mp


#### To unlock to check the integrity of the dataset. Are there differences between images and masks?
"""
def checkDataset(img_path, mask_path):
  file_set1 = set()
  for dirpath, dirnames, filenames in os.walk(img_path):
    for filename in filenames:
      file_name, file_extension = os.path.splitext(filename)
      file_set1.add(file_name)

  file_set2 = set()
  for dirpath, dirnames, filenames in os.walk(mask_path):
    for filename in filenames:
      file_name, file_extension = os.path.splitext(filename)
      file_set2.add(file_name)

  # compare the sets of file names
  unique_to_folder1 = file_set1 - file_set2
  unique_to_folder2 = file_set2 - file_set1


  # print the results
  print("Files unique to folder 1:", unique_to_folder1)
  print("Files unique to folder 2:", unique_to_folder2)

"""


# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"


def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

data_path = Path("/content/gdrive/MyDrive/FoodSeg103/Images/")

img_dir = data_path / "img_dir"
ann_dir = data_path / "ann_dir"


# RandomCustomCrop
class RandomCustomCrop(object):

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):

        img, mask = sample['image'], sample['mask']

        w = img.shape[0]
        h = img.shape[1]

        #print("w", w)
        #print("h", h)

        # New crop size passed in the constructor
        new_w, new_h = self.output_size

        if h == new_h and w == new_w:
            return sample

        if w < new_w or h < new_h:
            raise ValueError("Input image size is smaller than the desired crop size")
         #   #return sample

        x1 = random.randint(0, w - new_w)
        y1 = random.randint(0, h - new_h)

        # Convert to PIL Image
        img = Image.fromarray(img)
        mask = Image.fromarray(mask)

        # Crop img and mask
        img = F.crop(img, y1, x1, new_h, new_w)
        mask = F.crop(mask, y1, x1, new_h, new_w)

        # PIL to numpy array
        img = np.array(img)
        mask = np.array(mask)

        return {'image': img, 'mask': mask}


# RandomCustomRotation
class RandomCustomRotation(object):


    def __init__(self, degrees):
        self.degrees = degrees

    def __call__(self, sample):

        img, mask = sample['image'], sample['mask']

        angle = random.uniform(self.degrees[0], self.degrees[1])

        # Convert to PIL Image
        img = Image.fromarray(img)
        mask = Image.fromarray(mask)

        # Rotation
        img = F.rotate(img, angle)
        mask = F.rotate(mask, angle)

        # PIL to numpy array
        img = np.array(img)
        mask = np.array(mask)

        return {'image': img, 'mask': mask}


# RandomCustomHorizontalFlip
class RandomCustomHorizontalFlip(object):
    def __init__(self, p=0.5):
        self.p = p

    def __call__(self, sample):
        img, mask = sample['image'], sample['mask']

        #print("img s", img.shape)
        #print("mask s", mask.shape)

        if random.random() < self.p:

            # Transformation to tensors
            img = torch.from_numpy(img).float()
            mask = torch.from_numpy(mask).float()

            img = torch.flip(img, dims=[1])
            mask = torch.flip(mask, dims=[1])

            # Transform back
            img = img.numpy()
            mask = mask.numpy()

        return {'image': img, 'mask': mask}


# RandomCustomVerticalFlip
class RandomCustomVerticalFlip(object):
    def __init__(self, p=0.5):
        self.p = p

    def __call__(self, sample):
        img, mask = sample['image'], sample['mask']

        #print("img s", img.shape)
        #print("mask s", mask.shape)

        if random.random() < self.p:

            # Transformation to tensors
            img = torch.from_numpy(img).float()
            mask = torch.from_numpy(mask).float()

            img = torch.flip(img, dims=[0])
            mask = torch.flip(mask, dims=[0])

            # Transform back
            img = img.numpy()
            mask = mask.numpy()

        return {'image': img, 'mask': mask}



class RandomGaussianNoise(object):
    def __init__(self, mean=0.0, std=0.1):
      self.mean = mean
      self.std  = std

    def __call__(self, img):

      # Generate Gaussian noise with mean 0 and standard deviation 10 for each color channel
      noise = np.random.normal(0, 1, img.shape)

      # Scale the noise by a small factor (e.g., 0.05) to add a light layer of noise
      scaled_noise = 0.1 * noise

      # Add the noise to each color channel of the image
      noisy_img = np.clip(img.astype(np.int16) + scaled_noise, 0, 255).astype(np.uint8)

      img = noisy_img

      # Transform back
      #img = img.numpy()


      return img


# ElasticDeform
class ElasticDeform(object):
    def __init__(self, sigma, alpha):
        self.sigma = sigma
        self.alpha = alpha

    def __call__(self, sample):
        img, mask = sample['image'], sample['mask']

        #print(img.shape)
        #print(mask.shape)

        # We add a dimension at the end
        mask = np.expand_dims(mask, axis=-1)



        # Ensure that the input image is a 3D array with shape (height, width, channels)
        assert img.ndim == 3 and img.shape[2] == 3, "Input image must be a 3D RGB array with shape (height, width, 3)"

        # Ensure that the mask is a 3D array with shape (height, width, 1)
        assert mask.ndim == 3 and mask.shape[2] == 1, "Mask must be a 3D array with shape (height, width, 1)"

        # Reshape the input image into a 2D array with shape (height * width, channels)
        height, width, channels = img.shape
        flattened_img = img.reshape(-1)

        mask_rgb = np.repeat(mask, 3, axis=-1)
        flattened_mask = mask_rgb.reshape(-1)


        # Generate a random displacement field along the width and height dimensions
        #displacement = np.random.randn(2, height, width) * self.sigma

        # Combine images and masks into a single 3D array
        combined = np.concatenate((flattened_img, flattened_mask), axis=-1)

        # Apply deformation to combined array
        deformed_combined = elasticdeform.deform_random_grid(combined,
                                                     sigma=self.sigma,
                                                     order=3,
                                                     mode='nearest'
                                                     )

        # Split deformed array back into images and masks
        deformed_reshaped_img = deformed_combined[:height*width*channels].reshape((height, width, channels))
        deformed_reshaped_mask = deformed_combined[height*width*channels:].reshape((height, width, channels))

        #Convert mask to grayscale
        deformed_reshaped_mask = np.mean(deformed_reshaped_mask, axis=-1)
        deformed_reshaped_mask = np.expand_dims(deformed_reshaped_mask, axis=-1)

        #deformed_mask = np.squeeze(deformed_reshaped_mask, axis=-1)

        deformed_img = deformed_reshaped_img
        deformed_mask = deformed_reshaped_mask

        print("deformed_img", deformed_img.shape)
        print("deformed_mask", deformed_mask.shape)

        return {'image': deformed_img, 'mask': deformed_mask}




class CustomToTensor(object):
    #Convert ndarrays in sample to Tensors.


    def __new__(self, sample):
        img, mask = sample['image'], sample['mask']

        mask = np.expand_dims(mask, axis=-1)

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C x H x W
        img = img.transpose((2, 0, 1))
        mask = mask.transpose((2, 0, 1))

        return {'image': torch.from_numpy(img).float(),
                'mask': torch.from_numpy(mask).float()}


class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor


# Class SegIngredientDataset
class SegIngredientsDataset(Dataset):

    def __init__(self, img_dir, mask_dir, path, img_transform, mask_transform, common_transform, eval):

        self.eval = eval

        self.img_dir = img_dir / path
        self.mask_dir = mask_dir / path

        self.img_transform = img_transform
        self.mask_transform = mask_transform
        self.common_transform = common_transform

        print(self.img_dir)

        # Traverses and prints directory details
        #walk_through_dir(img_dir)

        #walk_through_dir(mask_dir)

        self.img_list = []
        self.mask_list = []

        self.dirs = [self.img_dir, self.mask_dir]

        self.num_processes = min(mp.cpu_count(), len(self.dirs))

    # Return the instance
    def Get(self):
        return self

    # Method called by the processs to do parallelization
    def run(self, obj):
        pool = mp.Pool(self.num_processes)

        pool.daemon = False

        manager = mp.Manager()
        p_img_list = manager.list()
        p_mask_list = manager.list()

        pool.starmap(self.read_files_from_folder, [(self.img_dir, p_img_list, cv2.IMREAD_COLOR), (self.mask_dir, p_mask_list, cv2.IMREAD_GRAYSCALE)])

        self.img_list = p_img_list
        self.mask_list = p_mask_list

        pool.close()
        pool.join()

    # Subprocess reading in the 2 different folders at the same time
    def read_files_from_folder(self, folder_path, custom_list, imread_type):
        counter = 0
        for entry in sorted(os.scandir(folder_path), key=lambda e: e.name):
            if entry.is_file():
              img_path = entry.path

              img_open = Image.open(img_path)
              img_open = img_open.resize((256, 256), resample=Image.NEAREST)

              img_array = np.array(img_open)
              custom_list.append(img_array)
              #print(filename, " | ", np.unique(img_array))
              print(img_path)


            #counter = counter + 1
            #if(counter >17):
            #  break


    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):

        img = self.img_list[idx]
        y = self.mask_list[idx]


        # Create sample array to perform modifications simultaneously on both images and masks
        sample = {}
        sample['image'] = img
        sample['mask'] = y

        #print("start")

        if(self.eval):
          sample_transformed = CustomToTensor(sample)
          img = sample_transformed['image']
          y = sample_transformed['mask']

          #print("bonjour")
          #print(img.shape)
          #print(y.shape)
          #print("bonjour1")

          return img, y

        if self.img_transform and self.mask_transform and self.common_transform is not None:

            # Perform modifications together
            sample_transformed = self.common_transform(sample)
            img = sample_transformed['image']
            y = sample_transformed['mask']

            img = self.img_transform(img)
            y = self.mask_transform(y)


       # print("conclusion")
       # if self.eval:
       #     return img, y, self.img_list[idx]
       # else:
        return img, y


# Parallelization

from multiprocessing import Process, Manager
from multiprocessing.managers import BaseManager

BaseManager.register('SegIngredientsDataset', SegIngredientsDataset)
manager = BaseManager()
manager.start()

#####
#Transformations
#########


#Normalization image

img_mean = [0.485, 0.456, 0.406]
img_std = [0.229, 0.224, 0.225]

#mask_mean = (0.5,)
#mask_std = (0.5,)


#RandomGaussianNoise(mean=0.0, std=1.0),
img_transform = transforms.Compose([

    transforms.ToTensor(),
    transforms.Normalize(img_mean, img_std)
])

# Mask transform
mask_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Common transform
#RandomCustomCrop((200,200)),
#RandomCustomRotation(degrees=(-50, 50)),

#RandomCustomVerticalFlip(),
#ElasticDeform(sigma=0.1, alpha=30),
common_transform = transforms.Compose([

    RandomCustomRotation(degrees=(-50, 50)),
    RandomCustomHorizontalFlip(),

])


# Classes handled by the process manager

#train_data = manager.SegIngredientsDataset(img_dir = img_dir, mask_dir = ann_dir, path = "train/", img_transform=img_transform, mask_transform=mask_transform, common_transform=common_transform, eval=False)
test_data  = manager.SegIngredientsDataset(img_dir = img_dir, mask_dir = ann_dir, path = "test/", img_transform=img_transform, mask_transform=mask_transform, common_transform=common_transform, eval=True)

#process1 = mp.Process(target=train_data.run, args=[train_data])
process2 = mp.Process(target=test_data.run, args=[test_data])
#process1.start()
process2.start()

#process1.join()
process2.join()

# Retrieve the 2 datasets (train and test)
#train_1 = train_data.Get()
test_1 = test_data.Get()
# Out:
# Collecting elasticdeform
#   Downloading elasticdeform-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.6/91.6 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from elasticdeform) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from elasticdeform) (1.10.1)
# Installing collected packages: elasticdeform
# Successfully installed elasticdeform-0.5.0
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00000048.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00000048.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00000263.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00000263.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00001977.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00001977.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00002106.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00002106.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004401.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004401.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004402.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004402.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004403.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004403.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004404.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004404.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004405.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004405.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004406.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004406.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004407.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004407.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004408.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004408.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004409.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004409.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004410.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004410.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004411.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004411.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004412.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004412.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004413.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004413.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004414.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004414.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004415.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004415.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004416.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004416.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004417.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004417.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004418.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004419.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004418.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004419.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004420.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004420.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004421.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004421.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004422.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004422.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004423.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004423.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004424.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004424.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004425.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004425.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004426.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004426.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004427.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004427.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004428.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004428.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004429.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004429.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004430.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004430.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004431.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004431.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004432.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004432.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004433.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004433.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004434.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004434.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004435.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004435.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004436.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004436.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004437.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004437.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004438.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004438.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004439.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004439.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004440.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004440.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004441.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004441.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004442.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004442.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004443.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004443.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004444.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004444.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004445.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004445.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004446.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004447.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004446.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004447.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004448.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004449.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004448.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004450.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004449.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004451.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004450.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004452.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004451.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004452.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004453.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004453.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004454.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004454.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004455.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004455.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004456.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004456.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004457.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004457.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004458.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004458.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004459.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004459.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004460.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004460.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004461.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004461.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004462.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004462.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004463.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004463.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004464.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004464.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004465.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004465.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004466.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004466.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004467.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004467.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004468.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004468.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004469.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004469.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004470.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004470.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004471.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004471.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004472.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004472.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004473.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004473.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004474.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004474.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004475.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004475.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004476.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004476.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004477.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004477.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004478.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004478.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004479.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004479.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004480.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004480.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004481.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004481.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004482.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004482.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004483.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004483.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004484.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004484.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004485.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004485.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004486.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004486.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004487.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004487.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004488.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004488.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004489.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004489.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004490.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004491.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004490.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004491.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004492.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004493.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004494.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004495.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004496.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004497.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004498.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004492.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004499.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004500.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004501.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004502.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004503.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004504.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004505.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004506.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004507.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004508.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004509.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004510.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004511.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004512.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004513.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004514.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004515.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004516.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004517.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004518.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004519.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004520.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004521.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004522.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004523.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004524.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004525.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004526.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004527.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004528.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004529.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004530.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004531.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004532.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004533.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004534.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004535.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004536.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004537.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004538.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004539.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004540.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004541.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004542.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004543.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004544.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004545.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004546.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004547.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004548.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004549.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004550.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004551.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004552.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004553.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004554.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004555.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004556.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004557.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004558.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004559.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004560.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004561.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004562.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004563.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004493.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004564.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004565.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004566.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004567.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004568.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004569.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004570.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004571.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004572.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004573.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004574.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004575.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004576.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004577.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004578.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004579.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004580.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004581.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004582.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004583.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004584.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004585.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004586.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004587.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004588.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004589.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004590.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004591.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004592.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004593.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004594.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004595.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004596.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004597.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004598.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004599.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004600.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004601.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004602.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004603.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004604.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004605.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004606.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004607.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004608.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004609.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004610.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004611.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004612.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004613.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004614.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004615.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004616.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004617.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004618.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004619.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004620.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004621.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004622.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004623.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004624.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004625.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004626.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004627.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004628.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004629.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004630.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004631.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004632.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004633.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004634.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004635.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004636.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004637.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004638.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004639.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004640.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004641.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004642.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004643.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004644.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004645.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004646.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004647.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004648.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004649.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004650.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004651.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004652.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004653.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004654.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004655.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004656.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004657.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004658.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004659.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004660.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004661.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004494.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004662.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004663.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004664.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004665.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004666.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004667.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004668.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004669.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004670.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004671.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004672.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004673.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004674.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004675.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004676.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004677.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004678.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004679.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004680.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004681.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004682.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004683.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004684.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004685.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004686.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004687.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004688.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004689.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004690.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004691.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004692.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004693.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004694.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004695.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004696.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004697.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004698.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004699.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004700.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004701.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004702.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004703.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004704.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004705.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004706.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004707.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004708.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004709.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004710.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004711.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004712.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004713.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004714.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004715.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004716.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004717.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004718.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004719.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004720.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004721.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004722.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004723.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004724.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004725.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004726.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004727.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004728.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004729.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004730.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004731.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004732.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004733.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004734.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004735.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004736.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004737.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004738.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004739.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004740.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004741.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004742.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004743.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004744.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004745.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004746.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004747.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004748.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004749.jpg/content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004495.png
#
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004750.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004751.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004752.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004753.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004754.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004755.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004756.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004757.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004758.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004759.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004760.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004761.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004762.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004763.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004764.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004765.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004766.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004767.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004768.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004769.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004770.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004771.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004772.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004773.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004774.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004775.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004776.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004777.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004778.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004779.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004780.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004781.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004782.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004783.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004784.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004785.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004786.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004787.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004788.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004789.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004790.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004791.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004792.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004793.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004794.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004795.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004796.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004797.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004798.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004799.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004800.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004801.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004802.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004803.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004804.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004805.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004806.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004807.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004808.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004809.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004810.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004811.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004812.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004813.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004814.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004815.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004816.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004817.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004818.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004819.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004820.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004821.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004822.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004823.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004824.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004825.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004826.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004827.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004828.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004829.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004830.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004831.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004832.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004833.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004496.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004834.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004835.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004836.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004837.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004838.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004839.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004840.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004841.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004842.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004843.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004844.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004845.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004846.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004847.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004848.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004849.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004850.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004851.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004852.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004853.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004854.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004855.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004856.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004857.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004858.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004859.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004860.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004861.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004862.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004863.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004864.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004865.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004866.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004867.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004868.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004869.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004870.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004871.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004872.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004873.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004874.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004875.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004876.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004877.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004878.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004879.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004880.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004881.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004882.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004883.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004884.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004885.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004886.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004887.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004888.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004889.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004890.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004891.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004892.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004893.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004894.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004895.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004896.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004897.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004898.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004899.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004900.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004901.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004902.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004903.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004497.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004904.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004905.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004906.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004907.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004908.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004909.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004910.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004911.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004912.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004913.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004914.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004915.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004916.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004917.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004918.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004919.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004920.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004921.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004922.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004923.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004924.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004925.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004926.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004927.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004928.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004929.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004930.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004931.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004932.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004933.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004934.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004935.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004936.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004937.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004938.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004939.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004940.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004941.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004942.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004943.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004944.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004945.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004946.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004947.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004948.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004949.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004950.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004951.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004952.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004953.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004954.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004955.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004956.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004957.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004958.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004959.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004960.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004961.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004962.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004963.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00004498.png
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004964.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004965.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004966.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004967.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004968.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004969.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004970.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004971.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004972.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004973.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004974.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004975.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004976.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004977.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004978.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004979.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004980.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004981.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004982.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004983.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004984.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004985.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004986.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004987.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004988.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004989.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004990.jpg
# /content/gdrive/MyDrive/FoodSeg103/Images/img_dir/test/00004991.jpg
# ...
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006883.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006884.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006885.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006886.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006887.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006888.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006889.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006890.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006891.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006892.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006893.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006894.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006895.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006896.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006897.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006898.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006899.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006900.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006901.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006902.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006903.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006904.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006905.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006906.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006907.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006908.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006909.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006910.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006911.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006912.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006913.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006914.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006915.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006916.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006917.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006918.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006919.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006920.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006921.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006922.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006923.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006924.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006925.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006926.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006927.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006928.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006929.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006930.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006931.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006932.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006933.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006934.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006935.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006936.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006937.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006938.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006939.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006940.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006941.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006942.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006943.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006944.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006945.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006946.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006947.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006948.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006949.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006950.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006951.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006952.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006953.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006954.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006955.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006956.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006957.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006958.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006959.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006960.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006961.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006962.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006963.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006964.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006965.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006966.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006967.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006968.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006969.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006970.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006971.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006972.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006973.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006974.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006975.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006976.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006977.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006978.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006979.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006980.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006981.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006982.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006983.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006984.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006985.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006986.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006987.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006988.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006989.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006990.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006991.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006992.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006993.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006994.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006995.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006996.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006997.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006998.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00006999.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007000.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007001.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007002.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007003.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007004.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007005.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007006.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007007.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007008.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007009.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007010.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007011.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007012.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007013.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007014.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007015.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007016.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007017.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007018.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007019.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007020.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007021.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007022.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007023.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007024.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007025.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007026.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007027.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007028.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007029.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007030.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007031.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007032.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007033.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007034.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007035.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007036.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007037.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007038.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007039.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007040.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007041.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007042.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007043.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007044.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007045.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007046.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007047.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007048.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007049.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007050.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007051.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007052.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007053.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007054.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007055.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007056.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007057.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007058.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007059.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007060.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007061.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007062.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007063.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007064.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007065.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007066.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007067.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007068.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007069.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007070.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007071.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007072.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007073.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007074.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007075.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007076.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007077.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007078.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007079.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007080.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007081.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007082.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007083.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007084.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007085.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007086.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007087.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007088.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007089.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007090.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007091.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007092.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007093.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007094.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007095.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007096.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007097.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007098.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007099.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007100.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007101.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007102.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007103.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007104.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007105.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007106.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007107.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007108.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007109.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007110.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007111.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007112.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007113.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007114.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007115.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007116.png
# /content/gdrive/MyDrive/FoodSeg103/Images/ann_dir/test/00007117.png

# %%
# Calculate pixel accuracy
def calculate_pixel_accuracy(y_truth, y_pred):

    matched_pixels = (y_truth == y_pred).sum().item()
    total_pixels = y_truth.nelement()
    #print("matched pixels", matched_pixels)
    match_ = (matched_pixels / total_pixels)

    return match_

# %%
# We create a test loader by passing the train dataset
test_loader = torch.utils.data.DataLoader(dataset = test_1,
                                            batch_size = 8,
                                            shuffle = False,
                                            drop_last=True) #shuffle ensures we traverse images in different order across epochs

# %%
 import torchvision.models as models

 #!pip install focal_loss_torch
 #from focal_loss.focal_loss import FocalLoss

 # !pip install segmentation-models-pytorch
 import segmentation_models_pytorch as smp

 from torch.optim.lr_scheduler import StepLR



 model = smp.DeepLabV3(encoder_name='resnet18',
        encoder_depth=5,
        encoder_weights=None,
        decoder_channels=256,
        in_channels=3,
        classes=104,
       activation=None,
       upsampling=8,
      aux_params=None)
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.15.2+cu118)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.9.2 (from segmentation-models-pytorch)
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.66.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (9.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.1+cu118)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation-models-pytorch) (6.0.1)
# Collecting huggingface-hub (from timm==0.9.2->segmentation-models-pytorch)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.5 MB/s eta 0:00:00
# Collecting safetensors (from timm==0.9.2->segmentation-models-pytorch)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation-models-pytorch) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16429 sha256=dda1dfa0f6079434388342821fea629e88eb5e02ec3b5ab51ca2bcf631e8e1fc
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=781f34db60b4acddf065a1af5463687a1c80da2e33fb3d59310e2f46acc480ac
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: safetensors, munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.16.4 munch-4.0.0 pretrainedmodels-0.7.4 safetensors-0.3.2 segmentation-models-pytorch-0.3.3 timm-0.9.2

# %%
state_dict = torch.load('/content/gdrive/MyDrive/Thesis_deeplearning_models/checkpoint_random_v2011_19.pth', map_location=torch.device('cpu') )

state_dict_real = state_dict['state_dict']
model.load_state_dict(state_dict_real)
model.to(device)
model.eval()

test_acc = 0
test_miou_acc_all = 0
test_miou_acc_ibg = 0

dataloader = test_loader

progress = 0

with torch.no_grad():
# Loop through DataLoader batches
    for batch, (X, y) in enumerate(dataloader):

          y = y.squeeze(dim=1)
          y = y.type(torch.LongTensor)

          # Send data to target device
          X, y = X.to(device), y.to(device)
          # 1. Forward pass
          test_pred_logits = model(X)

          # Calculate and accumulate accuracy

          predicted = torch.argmax(test_pred_logits, 1)

          test_acc += calculate_pixel_accuracy(y, predicted)

          test_tp, test_fp, test_fn, test_tn = smp.metrics.get_stats(predicted, y, mode='multiclass', num_classes=104)
          test_miou_acc_all += smp.metrics.iou_score(test_tp, test_fp, test_fn, test_tn, reduction="macro").item()

          predicted_i = predicted.clone() - 1
          y_i = y.clone() - 1

          test_tp_i, test_fp_i, test_fn_i, test_tn_i = smp.metrics.get_stats(predicted_i, y_i, mode='multiclass', num_classes=104, ignore_index=-1)
          test_miou_acc_ibg += smp.metrics.iou_score(test_tp_i, test_fp_i, test_fn_i, test_tn_i, reduction="macro").item()


          progress = progress + 1
          print("PROGRESS", progress)



# Adjust metrics to get average loss and accuracy per batch

test_acc = test_acc / len(dataloader)

test_miou_acc_all = test_miou_acc_all / len(dataloader)

test_miou_acc_ibg = test_miou_acc_ibg / len(dataloader)

test_iou_background = test_miou_acc_all - test_miou_acc_ibg


print("test_acc   :", test_acc)
print("test_miou_acc_all   :", test_miou_acc_all)
print("test_miou_acc_ibg   :", test_miou_acc_ibg)
print("test_iou_background :", test_iou_background)

# %%
# Unique pixel counter for each image array
def count_pixel_values(path, narray):
  counter = 0
  counts = {}

  if(path != None):
      img_open = Image.open(path)
      img_array = np.array(img_open)

  if(narray != None):
      img_array = narray

  # Collect unique pixels in each image array
  unique_values = np.unique(img_array)

  return unique_values


def calculate_class_coverage(path=None, narray=None):
    if path is not None:
        img_open = Image.open(path)
        img_array = np.array(img_open)
    elif narray is not None:
        img_array = narray
    else:
        raise ValueError("Either 'path' or 'narray' must be provided.")

    unique_values, pixel_counts = np.unique(img_array, return_counts=True)
    total_pixels = img_array.shape[0] * img_array.shape[1]
    print("total_pixels", total_pixels)
    print("pixel_counts", pixel_counts)
    coverage_percentage = {}
    for i, value in enumerate(unique_values):
        count = pixel_counts[i]
        class_coverage = (count / total_pixels) * 100
        coverage_percentage[value] = class_coverage

    return coverage_percentage


def vertical_flip(image, output_path):

    # Perform vertical flip
    flipped_image = image.transpose(Image.FLIP_TOP_BOTTOM)

    # Save the flipped image
    flipped_image.save(output_path)



def horizontal_flip(image, output_path):


    # Perform horizontal flip
    flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)

    # Save the flipped image
    flipped_image.save(output_path)




def random_crop(image, output_path, crop_size=(224, 224)):

    # Get the dimensions of the image
    image_width, image_height = image.size

    # Calculate the maximum starting coordinates for the crop
    max_x = image_width - crop_size[0]
    max_y = image_height - crop_size[1]

    # Generate random starting coordinates for the crop
    start_x = random.randint(0, max_x)
    start_y = random.randint(0, max_y)

    # Crop the image
    cropped_image = image.crop((start_x, start_y, start_x + crop_size[0], start_y + crop_size[1]))

    # Save the cropped image
    cropped_image.save(output_path)



def random_rotation(image, output_path, rotation_range=(-50, 50)):

    # Generate a random rotation angle within the specified range
    rotation_angle = random.uniform(rotation_range[0], rotation_range[1])

    # Perform the rotation
    rotated_image = image.rotate(rotation_angle, resample=Image.BILINEAR, expand=True)

    # Save the rotated image
    rotated_image.save(output_path)



import random
import numpy as np
from PIL import Image

def add_gaussian_noise(image, output_path, mean=0, std=25):

    # Convert the image to a NumPy array
    image_array = np.array(image)

    # Generate Gaussian noise
    noise = np.random.normal(mean, std, image_array.shape).astype(np.uint8)

    # Add the noise to the image
    noisy_image_array = np.clip(image_array + noise, 0, 255).astype(np.uint8)

    # Convert the NumPy array back to a PIL image
    noisy_image = Image.fromarray(noisy_image_array)

    # Save the noisy image
    noisy_image.save(output_path)




import random

# Load the pre-trained segmentation model
state_dict = torch.load('/content/gdrive/MyDrive/Thesis_deeplearning_models/checkpoint_random_v2011_19.pth', map_location=torch.device('cpu') )

# Set the model to evaluation mode

state_dict_real = state_dict['state_dict']
model.load_state_dict(state_dict_real)
model.eval()

# Load the image using PIL
image_path = '00004750.jpg'  # Replace with the actual path to your image
test_image_original = Image.open(image_path)
test_image_original_resized = test_image_original.resize((256, 256), resample=Image.NEAREST)

#add_gaussian_noise(test_image_original_resized, '00004750_gaussian_noise.jpg')

# Convert the PIL image to a NumPy array  -  (H, W, C)
test_image_original_resized = np.array(test_image_original_resized)


test_image = test_image_original_resized.transpose((2, 0, 1))
test_image = torch.from_numpy(test_image).float()
# Now tensor [C, H, W]
print("test image shape", test_image.shape)


"""
GROUND TRUTH
--------------------------------------------------
"""

# Load the image using PIL
image_path = '00004750_ann.png'  # Replace with the actual path to your image
ground_truth_original = Image.open(image_path)
ground_truth_original_resized = ground_truth_original.resize((256, 256), resample=Image.NEAREST)

# Convert the PIL image to a NumPy array  -  (H, W, C)
ground_truth_original_resized = np.array(ground_truth_original_resized)


ground_truth = np.expand_dims(ground_truth_original_resized, axis=-1)
ground_truth = ground_truth.transpose((2, 0, 1))
ground_truth = torch.from_numpy(ground_truth).float()
# Now tensor [C, H, W]
print("ground truth shape", ground_truth.shape)




# Prepare to pass to the model
test_image = test_image.unsqueeze(dim=0)
print("test image to pass to the model", test_image.shape)

# Convert the image to a PyTorch tensor
#img_tensor = test_image.cuda()
img_tensor = test_image

# Predict the segmentation mask
with torch.no_grad():
    output = model.forward(img_tensor)


print("output shape", output.shape)

# Remove the batch size dimension
prediction = output
# Apply softmax on output logits
# Classes dimension becomes first so dim=1
max_values = torch.argmax(prediction, dim=1)
prediction = max_values



print("ground truth shape", ground_truth.shape)
# Prediction gives a 1*256*256 output
print("prediction shape", prediction.shape)

# Pass the prediction to the cpu
prediction = prediction.cpu()




ground_truth = ground_truth.type(torch.LongTensor)






"""
--------------- METRICS --------------
"""

tp, fp, fn, tn = smp.metrics.get_stats(prediction, ground_truth, mode='multiclass', num_classes=103)
iiou_acc = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro").item()
ddice_acc = smp.metrics.f1_score(tp, fp, fn, tn, reduction="micro").item()
aacc = smp.metrics.accuracy(tp, fp, fn, tn, reduction="micro").item()


print("pixels in the ground truth array ", count_pixel_values(None, ground_truth.squeeze()))
print("Classes coverage in the ground truth array", calculate_class_coverage(None, ground_truth.squeeze()))

print("pixels in the prediction array ", count_pixel_values(None, prediction.squeeze()))
print("Classes coverage in the prediction array", calculate_class_coverage(None, prediction.squeeze()))



# Calculate pixel accuracy
print("SMP Pixel Accuracy", aacc)
print("SMP Intersection over union", iiou_acc)
print("SMP Dice coefficient metric", ddice_acc)





# Preparation test image
test_image = test_image.squeeze()
print("test_image+", test_image.shape)


#img_unnorm = UnNormalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))

#test_image = img_unnorm(test_image)

test_image = test_image.permute(1, 2, 0)

# normalize the tensor values to the range [0, 255]
test_image = test_image * 255.0

# convert the tensor to a numpy array
test_image = test_image.clamp(0, 255).byte().numpy()

#print(test_image)


## PLOT

plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Test Image Prepared')
plt.imshow(test_image)

plt.subplot(232)
plt.title('Test Image original')
plt.imshow(test_image_original_resized)

plt.subplot(233)
plt.title('Ground Truth')
plt.imshow(ground_truth.squeeze())

plt.subplot(234)
plt.title('Prediction on test image')
plt.imshow(prediction.squeeze())
plt.show()
# Out:
# test image shape torch.Size([3, 256, 256])
# ground truth shape torch.Size([1, 256, 256])
# test image to pass to the model torch.Size([1, 3, 256, 256])
# output shape torch.Size([1, 104, 256, 256])
# ground truth shape torch.Size([1, 256, 256])
# prediction shape torch.Size([1, 256, 256])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2765d8c06441> in <cell line: 218>()
#     216
#     217 tp, fp, fn, tn = smp.metrics.get_stats(prediction, ground_truth, mode='multiclass', num_classes=103)
# --> 218 iiou_acc = smp.metrics.iou_score(tp, fp, fn, tn, reduction="weighted").item()
#     219 ddice_acc = smp.metrics.f1_score(tp, fp, fn, tn, reduction="micro").item()
#     220 aacc = smp.metrics.accuracy(tp, fp, fn, tn, reduction="micro").item()
#
# /usr/local/lib/python3.10/dist-packages/segmentation_models_pytorch/metrics/functional.py in iou_score(tp, fp, fn, tn, reduction, class_weights, zero_division)
#     425 ) -> torch.Tensor:
#     426     """IoU score or Jaccard index"""  # noqa
# --> 427     return _compute_metric(
#     428         _iou_score,
#     429         tp,
#
# /usr/local/lib/python3.10/dist-packages/segmentation_models_pytorch/metrics/functional.py in _compute_metric(metric_fn, tp, fp, fn, tn, reduction, class_weights, zero_division, **metric_kwargs)
#     248
#     249     if class_weights is None and reduction is not None and "weighted" in reduction:
# --> 250         raise ValueError(f"Class weights should be provided for `{reduction}` reduction")
#     251
#     252     class_weights = class_weights if class_weights is not None else 1.0
#
# ValueError: Class weights should be provided for `weighted` reduction
