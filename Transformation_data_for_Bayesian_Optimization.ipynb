# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
from pathlib import Path
import json
import os


def process_experiment(experiment):
    # Convert keys to lowercase
    experiment = {k.lower(): v for k, v in experiment.items()}
    return experiment


data_path = Path("/content/gdrive/MyDrive/Thesis_deeplearning_models/")
filename_hyperparameters_experiments = data_path / 'hyperparameters_versions.txt'

# Read the file starting at experiment 1000

hyperparameters_experiments = []

# Read the contents of the file
with open(filename_hyperparameters_experiments, 'r') as file:
    content = file.read()


content = "[" + content + "]"

# Parse the content as JSON
hyperparameters_experiments = json.loads(content)

# Filter experiments with version below 1000
hyperparameters_experiments = [hyperparameters_experiment for hyperparameters_experiment in hyperparameters_experiments if hyperparameters_experiment["VERSION_EXPERIMENT"] >= 1000]

# Transform keys to lowercase and remove specified keys
filtered_hyperparameters_experiments = []
for hyperparameters in hyperparameters_experiments:
    filtered_hyperparameters = {key.lower(): value for key, value in hyperparameters.items() if key not in ["NUM_EPOCHS"]}
    filtered_hyperparameters_experiments.append(filtered_hyperparameters)



# Remove first duplicates
seen = set()
result = []
for filtered_hyperparameters in filtered_hyperparameters_experiments:
    if filtered_hyperparameters["version_experiment"] not in seen:
      seen.add(filtered_hyperparameters["version_experiment"])
      result.append(filtered_hyperparameters)


filtered_hyperparameters_experiments = result




"""

"""

def extractVersionFromRSFileName(filename_random_search):

    # Find the position of the underscore before the version
    underscore_index = filename_random_search.rfind("v")

    # Extract the version substring
    version = filename_random_search[underscore_index + 1 : -4]

    return version


# We retrieve all the txt files in the folder
file_list = []

for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.startswith('results_randomsearch') or file.startswith('results_bo'):
            file_path = os.path.join(root, file)
            file_list.append(file_path)

print(file_list)


experiments = []

# Loop through the files

for file_path in file_list:

    adapted_filename = "modified_data_v" + extractVersionFromRSFileName(file_path) + ".txt"
    test_post = data_path / adapted_filename

    # Read the text file
    with open(file_path, 'r') as file:
        content = file.read()

    # Add "[" at the beginning and "]" at the end
    content = '[' + content + ']'

    # Add delimiter "," between each symbol "}{"
    content = content.replace('}\n{', '},{')

    # Save the modified content to a new text file
    with open(test_post, 'w') as file:
        file.write(content)



    """
    read modified file && update the table
    """


    with open(test_post, 'r') as file:
        content_transformed = file.read()

    data_experiment = json.loads(content_transformed)

    for epoch in data_experiment:
            experiments.append(
                {
                  "version_experiment": int(extractVersionFromRSFileName(file_path)),
                  "epoch": epoch["epoch"],
                  "test_miou_acc_ibg": epoch["test_miou_acc_ibg"],

                }
                )






"""
Combining the 2 arrays to prepare the data for bayesian optimization
"""

for filtered_hyperparameters in filtered_hyperparameters_experiments:
  current_version = filtered_hyperparameters["version_experiment"]

  current_optimizer = filtered_hyperparameters["optimizer"]
  current_architecture_used = filtered_hyperparameters["architecture_used"]
  current_network = filtered_hyperparameters["network"]
  current_batch_size = filtered_hyperparameters["batch_size"]
  current_learning_rate = filtered_hyperparameters["learning_rate"]
  current_momentum = filtered_hyperparameters["momentum"]
  current_weight_decay = filtered_hyperparameters["weight_decay"]
  current_loss_function = filtered_hyperparameters["loss_function"]

  for experiment in experiments:

    if current_version == experiment["version_experiment"]:


        experiment["optimizer"] = current_optimizer
        experiment["architecture_used"] = current_architecture_used
        experiment["network"] = current_network
        experiment["batch_size"] = current_batch_size
        experiment["learning_rate"] = current_learning_rate
        experiment["momentum"] = current_momentum
        experiment["weight_decay"] = current_weight_decay
        experiment["loss_function"] = current_loss_function




count = 0
for exp in experiments:
  count = count + 1



print("number of total rows " + str(count))


# Printing data in txt_file
"""
Posting the table into a txt file
"""


post_training_data_file = data_path / "training_data_opti.txt"

with open(post_training_data_file, 'w') as file:
    # Write the experiments to the file using json.dump
    json.dump(experiments, file)
    file.write('\n')


#print(experiments)

for exp in experiments:
  print(exp)
# Out:
# ['/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1000.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1001.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1002.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1003.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1004.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1008.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1005.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1006.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1009.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1007.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1015.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1016.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1017.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1010.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1018.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1011.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1019.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1012.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1025.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1020.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1026.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1021.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1027.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1022.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1028.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1035.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1030.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1036.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1031.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1037.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1032.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1033.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1034.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1038.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1039.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1040.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1041.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1045.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1042.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1046.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1050.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1055.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1051.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1056.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1052.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1057.txt', '/content/gdrive/MyDrive/Thesis_deeplearning_models/results_randomsearch_v1053.txt', '/co ...
# number of total rows960
# {'version_experiment': 1000, 'epoch': 1, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 2, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 3, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 4, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 5, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 6, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 7, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 8, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 9, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 10, 'test_miou_acc_ibg': 0.00016632816268816498, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 11, 'test_miou_acc_ibg': 9.725456792987923e-05, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 12, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 13, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 14, 'test_miou_acc_ibg': 0.002203812573484322, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 15, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 16, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1000, 'epoch': 17, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.002345213433727622, 'momentum': 0.9, 'weight_decay': 0.009547827765345573, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 1, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 2, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 3, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 4, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 5, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 6, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 7, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 8, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 9, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 10, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 11, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 12, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1001, 'epoch': 13, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.35802242159843445, 'momentum': 0.9, 'weight_decay': 0.7112504243850708, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 1, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 2, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 3, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 4, 'test_miou_acc_ibg': 0.0005679049990645663, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 5, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 6, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 7, 'test_miou_acc_ibg': 0.018844863269443072, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 8, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 9, 'test_miou_acc_ibg': 0.00044574885533052964, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 10, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 11, 'test_miou_acc_ibg': 0.016018178982702188, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 12, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 13, 'test_miou_acc_ibg': 0.018863165461374235, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 14, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 15, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 16, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 17, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 18, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 19, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 20, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 21, 'test_miou_acc_ibg': 0.00046487478521397093, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 22, 'test_miou_acc_ibg': 0.020074754954415273, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 23, 'test_miou_acc_ibg': 0.007379410975936891, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 24, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 25, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 26, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1002, 'epoch': 27, 'test_miou_acc_ibg': 0.0046997414644322005, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.08218506723642349, 'momentum': 0.9, 'weight_decay': 0.0016589066945016384, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 1, 'test_miou_acc_ibg': 0.06142013013004886, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 2, 'test_miou_acc_ibg': 0.07984354792015233, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 3, 'test_miou_acc_ibg': 0.04196909426304545, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 4, 'test_miou_acc_ibg': 0.07204742931857513, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 5, 'test_miou_acc_ibg': 0.09319413756170809, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 6, 'test_miou_acc_ibg': 0.10535165156263822, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 7, 'test_miou_acc_ibg': 0.12247859803449644, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 8, 'test_miou_acc_ibg': 0.11711073924850364, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 9, 'test_miou_acc_ibg': 0.08604316465789452, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 10, 'test_miou_acc_ibg': 0.0700229131938326, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 11, 'test_miou_acc_ibg': 0.11180789357927336, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 12, 'test_miou_acc_ibg': 0.09957969662316732, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1003, 'epoch': 13, 'test_miou_acc_ibg': 0.10465626768055337, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0036500124260783195, 'momentum': 0.9, 'weight_decay': 0.17318595945835114, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 1, 'test_miou_acc_ibg': 0.12563596250527867, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 2, 'test_miou_acc_ibg': 0.09407882125608587, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 3, 'test_miou_acc_ibg': 0.12692560085240343, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 4, 'test_miou_acc_ibg': 0.14719005470615776, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 5, 'test_miou_acc_ibg': 0.15918983072276746, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 6, 'test_miou_acc_ibg': 0.1456097267800942, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 7, 'test_miou_acc_ibg': 0.18388355100313833, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 8, 'test_miou_acc_ibg': 0.18749744025290124, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 9, 'test_miou_acc_ibg': 0.17565765528050356, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 10, 'test_miou_acc_ibg': 0.16956177540823705, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 11, 'test_miou_acc_ibg': 0.19231923577844873, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 12, 'test_miou_acc_ibg': 0.2292219457020493, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 13, 'test_miou_acc_ibg': 0.17029223434585042, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 14, 'test_miou_acc_ibg': 0.2099423318264544, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 15, 'test_miou_acc_ibg': 0.19002947934441045, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 16, 'test_miou_acc_ibg': 0.18624904250666582, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 17, 'test_miou_acc_ibg': 0.2133066992492492, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 18, 'test_miou_acc_ibg': 0.18600104176754453, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1004, 'epoch': 19, 'test_miou_acc_ibg': 0.20669725726015473, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.00017609928909223527, 'momentum': 0.9, 'weight_decay': 0.00019621889805421233, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 1, 'test_miou_acc_ibg': 0.024699071936622144, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 2, 'test_miou_acc_ibg': 0.07152776772386076, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 3, 'test_miou_acc_ibg': 0.10045737185742414, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 4, 'test_miou_acc_ibg': 0.05524619116317254, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 5, 'test_miou_acc_ibg': 0.0961587905094177, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 6, 'test_miou_acc_ibg': 0.12251527392000935, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 7, 'test_miou_acc_ibg': 0.08371390745982844, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 8, 'test_miou_acc_ibg': 0.06615008325171465, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 9, 'test_miou_acc_ibg': 0.12428659910984721, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 10, 'test_miou_acc_ibg': 0.10162287679779139, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 11, 'test_miou_acc_ibg': 0.1215739693594057, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 12, 'test_miou_acc_ibg': 0.13638706667734027, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 13, 'test_miou_acc_ibg': 0.10992718138600967, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 14, 'test_miou_acc_ibg': 0.11797878623759012, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 15, 'test_miou_acc_ibg': 0.1215646405546842, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 16, 'test_miou_acc_ibg': 0.12345918708989365, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 17, 'test_miou_acc_ibg': 0.1344302439191562, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 18, 'test_miou_acc_ibg': 0.09594844408307857, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 19, 'test_miou_acc_ibg': 0.07939642349892347, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 20, 'test_miou_acc_ibg': 0.10051800326516279, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1008, 'epoch': 21, 'test_miou_acc_ibg': 0.12211604038849891, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.011803730390965939, 'momentum': 0.9, 'weight_decay': 0.00031777838012203574, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 1, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 2, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 3, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 4, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 5, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 6, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 7, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 8, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 9, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 10, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 11, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 12, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 13, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 14, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1005, 'epoch': 15, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.008034182712435722, 'momentum': 0.9, 'weight_decay': 0.04918031394481659, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 1, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 2, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 3, 'test_miou_acc_ibg': 6.771646565170144e-05, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 4, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 5, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 6, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 7, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 8, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 9, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 10, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 11, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 12, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 13, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 14, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1006, 'epoch': 15, 'test_miou_acc_ibg': 0.0, 'optimizer': 'Adam', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 8, 'learning_rate': 0.0014366775285452604, 'momentum': 0.9, 'weight_decay': 0.022084956988692284, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1009, 'epoch': 1, 'test_miou_acc_ibg': 0.04170718801659523, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.016527576372027397, 'momentum': 0.9, 'weight_decay': 0.0008455148199573159, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1009, 'epoch': 2, 'test_miou_acc_ibg': 0.015072222540458233, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.016527576372027397, 'momentum': 0.9, 'weight_decay': 0.0008455148199573159, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1009, 'epoch': 3, 'test_miou_acc_ibg': 0.06515658623242003, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.016527576372027397, 'momentum': 0.9, 'weight_decay': 0.0008455148199573159, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1009, 'epoch': 4, 'test_miou_acc_ibg': 0.0419218330395419, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.016527576372027397, 'momentum': 0.9, 'weight_decay': 0.0008455148199573159, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1009, 'epoch': 5, 'test_miou_acc_ibg': 0.001492105818936291, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 4, 'learning_rate': 0.016527576372027397, 'momentum': 0.9, 'weight_decay': 0.0008455148199573159, 'loss_function': 'CrossEntropyLoss'}
# ...
# {'version_experiment': 1065, 'epoch': 11, 'test_miou_acc_ibg': 0.18640656388343724, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 12, 'test_miou_acc_ibg': 0.22254464175916255, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 13, 'test_miou_acc_ibg': 0.18353341407793805, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 14, 'test_miou_acc_ibg': 0.20896470468295247, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 15, 'test_miou_acc_ibg': 0.1998347743953529, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 16, 'test_miou_acc_ibg': 0.21203315627754182, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 17, 'test_miou_acc_ibg': 0.20905459761843645, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 18, 'test_miou_acc_ibg': 0.23854604397053109, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 19, 'test_miou_acc_ibg': 0.24688471691276795, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 20, 'test_miou_acc_ibg': 0.24191107651344815, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 21, 'test_miou_acc_ibg': 0.2275968823385866, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1065, 'epoch': 22, 'test_miou_acc_ibg': 0.21326135860798054, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.007723462767899036, 'momentum': 0.9, 'weight_decay': 0.00018765311688184738, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 1, 'test_miou_acc_ibg': 0.07940392852393224, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 2, 'test_miou_acc_ibg': 0.1198222516104579, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 3, 'test_miou_acc_ibg': 0.134199421719781, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 4, 'test_miou_acc_ibg': 0.14697166035806103, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 5, 'test_miou_acc_ibg': 0.17255320633005322, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 6, 'test_miou_acc_ibg': 0.1870854320144631, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 7, 'test_miou_acc_ibg': 0.16349195506899877, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 8, 'test_miou_acc_ibg': 0.19510067998662703, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 9, 'test_miou_acc_ibg': 0.217812831996751, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 10, 'test_miou_acc_ibg': 0.21678857303651652, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 11, 'test_miou_acc_ibg': 0.2152382486072698, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 12, 'test_miou_acc_ibg': 0.21360131664047563, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 13, 'test_miou_acc_ibg': 0.2283292526057116, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 14, 'test_miou_acc_ibg': 0.2304468622529193, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 15, 'test_miou_acc_ibg': 0.22882783838680812, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 16, 'test_miou_acc_ibg': 0.22709346458988083, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 17, 'test_miou_acc_ibg': 0.22676444300135276, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 18, 'test_miou_acc_ibg': 0.20290382486536987, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 19, 'test_miou_acc_ibg': 0.2272306601691963, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 20, 'test_miou_acc_ibg': 0.2499723732471466, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 21, 'test_miou_acc_ibg': 0.21239881357528212, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 22, 'test_miou_acc_ibg': 0.24771887254446073, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 23, 'test_miou_acc_ibg': 0.2266431974065035, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 24, 'test_miou_acc_ibg': 0.21849443270523744, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 25, 'test_miou_acc_ibg': 0.23346656892112547, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 26, 'test_miou_acc_ibg': 0.22157899975160458, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 27, 'test_miou_acc_ibg': 0.19942378274452194, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 28, 'test_miou_acc_ibg': 0.199637477895371, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1066, 'epoch': 29, 'test_miou_acc_ibg': 0.20364069865834444, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.0019501758506521583, 'momentum': 0.9, 'weight_decay': 0.00355810415931046, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 1, 'test_miou_acc_ibg': 0.09630650883671588, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 2, 'test_miou_acc_ibg': 0.13564352440486724, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 3, 'test_miou_acc_ibg': 0.1652482462332661, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 4, 'test_miou_acc_ibg': 0.1923285203642751, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 5, 'test_miou_acc_ibg': 0.18799534731341483, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 6, 'test_miou_acc_ibg': 0.19081307234788747, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 7, 'test_miou_acc_ibg': 0.21632239852744833, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 8, 'test_miou_acc_ibg': 0.22791006152791188, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 9, 'test_miou_acc_ibg': 0.19901433466632562, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
# {'version_experiment': 1067, 'epoch': 10, 'test_miou_acc_ibg': 0.19925192485850557, 'optimizer': 'SGD', 'architecture_used': 'DeepLabV3', 'network': 'resnet18', 'batch_size': 16, 'learning_rate': 0.004271659534424543, 'momentum': 0.9, 'weight_decay': 0.000999408308416605, 'loss_function': 'CrossEntropyLoss'}
